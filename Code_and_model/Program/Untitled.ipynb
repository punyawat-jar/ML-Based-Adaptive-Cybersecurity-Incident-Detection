# %%
import pandas as pd

# %%
train = pd.read_csv("./kdd/train_test_folder/train_kdd/train.csv")
test = pd.read_csv("./kdd/train_test_folder/test_kdd/test.csv")

# %%
train.label.value_counts()
# Out:
# label
# normal             53937
# neptune            32109
# satan               3058
# ipsweep             2618
# smurf               2318
# portsweep           2162
# nmap                1096
# back                 920
# guess_passwd         899
# mscan                697
# warezmaster          675
# teardrop             633
# warezclient          623
# apache2              516
# processtable         479
# snmpguess            232
# saint                223
# mailbomb             205
# pod                  169
# snmpgetattack        125
# httptunnel            93
# buffer_overflow       35
# multihop              18
# land                  18
# rootkit               16
# named                 12
# ps                    11
# sendmail              10
# xterm                  9
# imap                   8
# ftp_write              8
# loadmodule             8
# xlock                  6
# phf                    4
# perl                   4
# xsnoop                 3
# ...

# %%
test.label.value_counts()
# Out:
# label
# normal             23117
# neptune            13762
# satan               1310
# ipsweep             1122
# smurf                993
# portsweep            926
# nmap                 470
# back                 395
# guess_passwd         385
# mscan                299
# warezmaster          289
# teardrop             271
# warezclient          267
# apache2              221
# processtable         206
# snmpguess             99
# saint                 96
# mailbomb              88
# pod                   73
# snmpgetattack         53
# httptunnel            40
# buffer_overflow       15
# multihop               7
# land                   7
# rootkit                7
# named                  5
# xterm                  4
# imap                   4
# sendmail               4
# ps                     4
# ftp_write              3
# xlock                  3
# loadmodule             3
# phf                    2
# worm                   1
# perl                   1
# ...

# %%
len(test.label.value_counts().index)
# Out:
# 40

# %%
len(train.label.value_counts().index)
# Out:
# 40

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix

# %%
xlock = pd.read_csv('./kdd/dataset/mix_dataset/xlock.csv')
X_main= xlock.drop('label', axis =1)
y_main= xlock.label

# %%
X_train_main, X_test_main, y_train_main, y_test_main = train_test_split(X_main, y_main, test_size=0.3, random_state=42, stratify=y_main)

# %%
DT = DecisionTreeClassifier()

# %%
DT.fit(X_train_main, y_train_main)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = DT.predict(X_test_main)

# %%
y_pred
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
accuracy_score(y_test_main, y_pred)
# Out:
# 0.9998877816680133
