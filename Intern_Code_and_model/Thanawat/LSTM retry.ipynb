# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense
from sklearn import model_selection, feature_selection, kernel_approximation, ensemble, linear_model, metrics, utils
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
for i in range (1,14):
    X = pd.read_hdf(f'/home/s2316001/codepaper/data_window_botnet{i}.h5', key='data')
    X.reset_index(drop=True, inplace=True)

    X2 = pd.read_hdf(f'/home/s2316001/codepaper/data_window3_botnet{i}.h5', key='data')
    X2.reset_index(drop=True, inplace=True)

    X = X.join(X2)

    X.drop('window_id', axis=1, inplace=True)

    y = X['Label_<lambda>']
    X.drop('Label_<lambda>', axis=1, inplace=True)
    labels = np.load(f"/home/s2316001/codepaper/data_window_botnet{i}_labels.npy", allow_pickle=True)

    #print("combined_labels:",combined_labels)
    # Split the combined data into train and test sets
    y_bin6 = y == np.where(labels == 'flow=From-Botne')[0][0]
    X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y_bin6, test_size=0.33, random_state=43,shuffle=False)
    X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
    X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))
    #X_train_new, y_train_new = utils.resample(X_train, y_train, n_samples=X_train.shape[0]*10, random_state=tab_seed[i])
    # Build the LSTM model
    model = Sequential()
    model.add(LSTM(256, input_shape=(1, X_train.shape[2]), activation='relu', return_sequences=True))
    model.add(LSTM(128))
    model.add(Dense(1, activation='sigmoid'))
    # Compile the model
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    # Train the model
    history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=32)
    _, train_acc = model.evaluate(X_train, y_train, verbose=0)
    _, test_acc = model.evaluate(X_test, y_test, verbose=0)
    print('Accuracy Train: %.3f, Test: %.3f' % (train_acc, test_acc))
        # plot loss during training
    # plt.subplot(211)
    # plt.title('Loss')
    # plt.plot(history.history['loss'], label='train')
    # plt.plot(history.history['val_loss'], label='test')
    # plt.legend()
    # # plot accuracy during training
    # plt.subplot(212)
    # plt.title('Accuracy')
    # plt.plot(history.history['accuracy'], label='train')
    # plt.plot(history.history['val_accuracy'], label='test')
    # plt.legend()
    # plt.show()
    # Plot the loss and accuracy
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.savefig(f'/home/s2316001/codepaper/graph/LSTM_loss_accuracy_plot{i}.png')  # Save the plot as an image file
    plt.show()
#     # predict probabilities for test set
#     yhat_probs = model.predict(X_test, verbose=0)
#     # predict crisp classes for test set
#     yhat_classes = (model.predict(X_test) > 0.5).astype("int32")
#     reduce to 1d array
#     yhat_probs = yhat_probs.reshape(yhat_probs.shape[0])
#     yhat_classes = yhat_classes.reshape(yhat_classes.shape[0])
#     print(f"---------------------- File {i} --------------------------")
#     # accuracy: (tp + tn) / (p + n)
#     accuracy = accuracy_score(y_test, yhat_classes)
#     print('Accuracy: %f' % accuracy)
#     # precision tp / (tp + fp)
#     precision = precision_score(y_test, yhat_classes)
#     print('Precision: %f' % precision)
#     # recall: tp / (tp + fn)
#     recall = recall_score(y_test, yhat_classes)
#     print('Recall: %f' % recall)
#     # f1: 2 tp / (2 tp + fp + fn)
#     f1 = f1_score(y_test, yhat_classes)
#     print('F1 score: %f' % f1)

#     confusion matrix
#     matrix = confusion_matrix(y_test, yhat_classes)
#     print(matrix)
#     Plot Confusion Matrix
#     plt.figure(figsize=(10, 8))
#     sns.heatmap(matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
#     plt.title('Confusion Matrix')
#     plt.xlabel('Predicted Labels')
#     plt.ylabel('True Labels')
#     plt.savefig(f'/home/s2316001/codepaper/graph/lstm_confusion_matrix{i}.png')
#     plt.show()
    # Save the model
    model.save(f'/home/s2316001/codepaper/LSTM_2/lstm_model{i}.h5')
# Out:
# 2023-07-05 12:57:00.654515: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/10
# 46622/46622 [==============================] - 251s 5ms/step - loss: 6.3839e-04 - accuracy: 0.9999 - val_loss: 6.2781e-05 - val_accuracy: 1.0000
# Epoch 2/10
# 46622/46622 [==============================] - 252s 5ms/step - loss: 1.2744e-04 - accuracy: 1.0000 - val_loss: 7.2934e-05 - val_accuracy: 1.0000
# Epoch 3/10
# 46622/46622 [==============================] - 264s 6ms/step - loss: 1.2372e-04 - accuracy: 1.0000 - val_loss: 5.7513e-05 - val_accuracy: 1.0000
# Epoch 4/10
# 46622/46622 [==============================] - 265s 6ms/step - loss: 1.1188e-04 - accuracy: 1.0000 - val_loss: 1.9847e-04 - val_accuracy: 0.9999
# Epoch 5/10
# 46622/46622 [==============================] - 289s 6ms/step - loss: 8.9294e-05 - accuracy: 1.0000 - val_loss: 5.0500e-04 - val_accuracy: 0.9999
# Epoch 6/10
# 46622/46622 [==============================] - 309s 7ms/step - loss: 1.0507e-04 - accuracy: 1.0000 - val_loss: 1.3037e-04 - val_accuracy: 1.0000
# Epoch 7/10
# 46622/46622 [==============================] - 287s 6ms/step - loss: 9.8416e-05 - accuracy: 1.0000 - val_loss: 3.2365e-05 - val_accuracy: 1.0000
# Epoch 8/10
# 46622/46622 [==============================] - 283s 6ms/step - loss: 9.5538e-05 - accuracy: 1.0000 - val_loss: 2.5203e-05 - val_accuracy: 1.0000
# Epoch 9/10
# 46622/46622 [==============================] - 303s 7ms/step - loss: 8.5070e-05 - accuracy: 1.0000 - val_loss: 3.3803e-05 - val_accuracy: 1.0000
# Epoch 10/10
# 46622/46622 [==============================] - 314s 7ms/step - loss: 8.3716e-05 - accuracy: 1.0000 - val_loss: 4.1340e-05 - val_accuracy: 1.0000
# Accuracy Train: 1.000, Test: 1.000
# Epoch 1/10
# 29973/29973 [==============================] - 214s 7ms/step - loss: 0.0010 - accuracy: 0.9999 - val_loss: 1.7143e-04 - val_accuracy: 0.9999
# Epoch 2/10
# 29973/29973 [==============================] - 218s 7ms/step - loss: 3.0579e-04 - accuracy: 0.9999 - val_loss: 8.8950e-04 - val_accuracy: 0.9998
# Epoch 3/10
# 29973/29973 [==============================] - 209s 7ms/step - loss: 2.4442e-04 - accuracy: 1.0000 - val_loss: 1.6927e-04 - val_accuracy: 1.0000
# Epoch 4/10
# 29973/29973 [==============================] - 205s 7ms/step - loss: 2.2963e-04 - accuracy: 1.0000 - val_loss: 6.1681e-05 - val_accuracy: 1.0000
# Epoch 5/10
# 29973/29973 [==============================] - 198s 7ms/step - loss: 2.1185e-04 - accuracy: 1.0000 - val_loss: 4.3394e-05 - val_accuracy: 1.0000
# Epoch 6/10
# 29973/29973 [==============================] - 214s 7ms/step - loss: 2.0711e-04 - accuracy: 1.0000 - val_loss: 2.1299e-04 - val_accuracy: 0.9999
# Epoch 7/10
# 29973/29973 [==============================] - 221s 7ms/step - loss: 1.9873e-04 - accuracy: 1.0000 - val_loss: 2.1940e-04 - val_accuracy: 0.9999
# Epoch 8/10
# 29973/29973 [==============================] - 217s 7ms/step - loss: 1.9000e-04 - accuracy: 1.0000 - val_loss: 1.2238e-04 - val_accuracy: 1.0000
# Epoch 9/10
# 29973/29973 [==============================] - 213s 7ms/step - loss: 2.1460e-04 - accuracy: 1.0000 - val_loss: 6.9933e-05 - val_accuracy: 1.0000
# Epoch 10/10
# 29973/29973 [==============================] - 215s 7ms/step - loss: 1.9321e-04 - accuracy: 1.0000 - val_loss: 1.3861e-04 - val_accuracy: 1.0000
# Accuracy Train: 1.000, Test: 1.000
# Epoch 1/10
# 42379/42379 [==============================] - 290s 7ms/step - loss: 0.0015 - accuracy: 0.9998 - val_loss: 4.1100e-04 - val_accuracy: 1.0000
# Epoch 2/10
# 42379/42379 [==============================] - 274s 6ms/step - loss: 9.4830e-04 - accuracy: 0.9999 - val_loss: 3.9245e-04 - val_accuracy: 1.0000
# Epoch 3/10
# 42379/42379 [==============================] - 275s 6ms/step - loss: 9.5538e-04 - accuracy: 0.9999 - val_loss: 4.0295e-04 - val_accuracy: 1.0000
# Epoch 4/10
# 42379/42379 [==============================] - 289s 7ms/step - loss: 9.4848e-04 - accuracy: 0.9999 - val_loss: 3.6586e-04 - val_accuracy: 1.0000
# Epoch 5/10
# 42379/42379 [==============================] - 294s 7ms/step - loss: 9.5025e-04 - accuracy: 0.9999 - val_loss: 3.9073e-04 - val_accuracy: 1.0000
# Epoch 6/10
# 42379/42379 [==============================] - 295s 7ms/step - loss: 9.2045e-04 - accuracy: 0.9999 - val_loss: 3.7894e-04 - val_accuracy: 1.0000
# Epoch 7/10
# 42379/42379 [==============================] - 232s 5ms/step - loss: 9.4562e-04 - accuracy: 0.9999 - val_loss: 4.2354e-04 - val_accuracy: 1.0000
# Epoch 8/10
# 42379/42379 [==============================] - 227s 5ms/step - loss: 9.2565e-04 - accuracy: 0.9999 - val_loss: 4.2949e-04 - val_accuracy: 1.0000
# Epoch 9/10
# 42379/42379 [==============================] - 250s 6ms/step - loss: 8.9563e-04 - accuracy: 0.9999 - val_loss: 3.9241e-04 - val_accuracy: 1.0000
# Epoch 10/10
# 42379/42379 [==============================] - 266s 6ms/step - loss: 9.0323e-04 - accuracy: 0.9999 - val_loss: 3.9297e-04 - val_accuracy: 1.0000
# Accuracy Train: 1.000, Test: 1.000
# Epoch 1/10
# 9855/9855 [==============================] - 69s 7ms/step - loss: 0.0034 - accuracy: 0.9998 - val_loss: 0.0030 - val_accuracy: 0.9996
# Epoch 2/10
# 9855/9855 [==============================] - 68s 7ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.0037 - val_accuracy: 0.9996
# Epoch 3/10
# 9855/9855 [==============================] - 70s 7ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0031 - val_accuracy: 0.9996
# Epoch 4/10
# 9855/9855 [==============================] - 67s 7ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.0032 - val_accuracy: 0.9996
# Epoch 5/10
# 9855/9855 [==============================] - 64s 6ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.0033 - val_accuracy: 0.9996
# Epoch 6/10
# 9855/9855 [==============================] - 65s 7ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.0031 - val_accuracy: 0.9997
# Epoch 7/10
# 9855/9855 [==============================] - 66s 7ms/step - loss: 9.8373e-04 - accuracy: 0.9998 - val_loss: 0.0031 - val_accuracy: 0.9996
# Epoch 8/10
# 9855/9855 [==============================] - 67s 7ms/step - loss: 9.4918e-04 - accuracy: 0.9999 - val_loss: 0.0030 - val_accuracy: 0.9996
# Epoch 9/10
# 9855/9855 [==============================] - 64s 7ms/step - loss: 9.2788e-04 - accuracy: 0.9998 - val_loss: 0.0036 - val_accuracy: 0.9996
# Epoch 10/10
# 9855/9855 [==============================] - 65s 7ms/step - loss: 8.9425e-04 - accuracy: 0.9999 - val_loss: 0.0032 - val_accuracy: 0.9996
# Accuracy Train: 1.000, Test: 1.000
# Epoch 1/10
# 1333/1333 [==============================] - 13s 7ms/step - loss: 0.0172 - accuracy: 0.9997 - val_loss: 0.0023 - val_accuracy: 0.9995
# Epoch 2/10
# 1333/1333 [==============================] - 9s 7ms/step - loss: 9.6660e-04 - accuracy: 0.9997 - val_loss: 0.0030 - val_accuracy: 0.9995
# Epoch 3/10
# 1333/1333 [==============================] - 9s 7ms/step - loss: 8.9286e-04 - accuracy: 0.9998 - val_loss: 0.0023 - val_accuracy: 0.9994
# Epoch 4/10
# 1333/1333 [==============================] - 9s 7ms/step - loss: 6.5766e-04 - accuracy: 0.9998 - val_loss: 0.0028 - val_accuracy: 0.9995
# Epoch 5/10
# 1333/1333 [==============================] - 9s 7ms/step - loss: 7.1442e-04 - accuracy: 0.9999 - val_loss: 0.0026 - val_accuracy: 0.9997
# Epoch 6/10
# 1333/1333 [==============================] - 9s 7ms/step - loss: 7.4848e-04 - accuracy: 0.9999 - val_loss: 0.0028 - val_accuracy: 0.9997
# Epoch 7/10
# 1333/1333 [==============================] - 9s 7ms/step - loss: 6.0447e-04 - accuracy: 0.9999 - val_loss: 0.0020 - val_accuracy: 0.9997
# Epoch 8/10
# 1333/1333 [==============================] - 9s 7ms/step - loss: 4.9094e-04 - accuracy: 0.9998 - val_loss: 0.0026 - val_accuracy: 0.9997
# Epoch 9/10
# 1333/1333 [==============================] - 9s 7ms/step - loss: 4.3116e-04 - accuracy: 0.9999 - val_loss: 0.0028 - val_accuracy: 0.9997
# Epoch 10/10
# 1333/1333 [==============================] - 9s 7ms/step - loss: 4.6931e-04 - accuracy: 0.9999 - val_loss: 0.0027 - val_accuracy: 0.9997
# Accuracy Train: 1.000, Test: 1.000
# Epoch 1/10
# 4625/4625 [==============================] - 32s 6ms/step - loss: 0.0049 - accuracy: 0.9997 - val_loss: 5.4456e-04 - val_accuracy: 0.9999
# Epoch 2/10
# 4625/4625 [==============================] - 30s 6ms/step - loss: 4.2020e-04 - accuracy: 0.9999 - val_loss: 4.6408e-04 - val_accuracy: 0.9999
# Epoch 3/10
# 4625/4625 [==============================] - 31s 7ms/step - loss: 4.2694e-04 - accuracy: 0.9999 - val_loss: 4.2214e-04 - val_accuracy: 1.0000
# Epoch 4/10
# 4625/4625 [==============================] - 32s 7ms/step - loss: 4.1388e-04 - accuracy: 0.9999 - val_loss: 4.0460e-04 - val_accuracy: 1.0000
# Epoch 5/10
# 4625/4625 [==============================] - 31s 7ms/step - loss: 3.7264e-04 - accuracy: 0.9999 - val_loss: 4.9276e-04 - val_accuracy: 0.9999
# Epoch 6/10
# 4625/4625 [==============================] - 31s 7ms/step - loss: 4.3800e-04 - accuracy: 0.9999 - val_loss: 4.2761e-04 - val_accuracy: 1.0000
# Epoch 7/10
# 4625/4625 [==============================] - 31s 7ms/step - loss: 4.9755e-04 - accuracy: 0.9999 - val_loss: 4.1502e-04 - val_accuracy: 0.9999
# Epoch 8/10
# 4625/4625 [==============================] - 31s 7ms/step - loss: 4.0915e-04 - accuracy: 0.9999 - val_loss: 5.3586e-04 - val_accuracy: 0.9999
# Epoch 9/10
# 4625/4625 [==============================] - 31s 7ms/step - loss: 4.0693e-04 - accuracy: 0.9999 - val_loss: 3.5754e-04 - val_accuracy: 0.9999
# Epoch 10/10
# 4625/4625 [==============================] - 32s 7ms/step - loss: 3.0231e-04 - accuracy: 0.9999 - val_loss: 3.9915e-04 - val_accuracy: 1.0000
# Accuracy Train: 1.000, Test: 1.000
# Epoch 1/10
# 1061/1061 [==============================] - 11s 8ms/step - loss: 0.0212 - accuracy: 0.9993 - val_loss: 3.3060e-04 - val_accuracy: 1.0000
# Epoch 2/10
# 1061/1061 [==============================] - 8s 8ms/step - loss: 0.0016 - accuracy: 0.9998 - val_loss: 5.2616e-04 - val_accuracy: 1.0000
# Epoch 3/10
# 1061/1061 [==============================] - 7s 7ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 1.9566e-04 - val_accuracy: 1.0000
# Epoch 4/10
# 1061/1061 [==============================] - 7s 7ms/step - loss: 0.0014 - accuracy: 0.9998 - val_loss: 1.0213e-04 - val_accuracy: 1.0000
# Epoch 5/10
# 1061/1061 [==============================] - 7s 7ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 1.6509e-04 - val_accuracy: 1.0000
# Epoch 6/10
# 1061/1061 [==============================] - 8s 7ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 4.1726e-04 - val_accuracy: 1.0000
# Epoch 7/10
# 1061/1061 [==============================] - 7s 7ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 4.2405e-04 - val_accuracy: 1.0000
# Epoch 8/10
# 1061/1061 [==============================] - 8s 7ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 2.2010e-04 - val_accuracy: 1.0000
# Epoch 9/10
# 1061/1061 [==============================] - 7s 7ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 1.3284e-04 - val_accuracy: 0.9999
# Epoch 10/10
# 1061/1061 [==============================] - 7s 7ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 2.1432e-04 - val_accuracy: 1.0000
# Accuracy Train: 1.000, Test: 1.000
# Epoch 1/10
# 34413/34413 [==============================] - 236s 7ms/step - loss: 0.0036 - accuracy: 0.9995 - val_loss: 0.0037 - val_accuracy: 0.9993
# Epoch 2/10
# 34413/34413 [==============================] - 257s 7ms/step - loss: 0.0027 - accuracy: 0.9995 - val_loss: 0.0034 - val_accuracy: 0.9993
# Epoch 3/10
# 34413/34413 [==============================] - 310s 9ms/step - loss: 0.0026 - accuracy: 0.9995 - val_loss: 0.0033 - val_accuracy: 0.9992
# Epoch 4/10
# 34413/34413 [==============================] - 315s 9ms/step - loss: 0.0025 - accuracy: 0.9995 - val_loss: 0.0031 - val_accuracy: 0.9993
# Epoch 5/10
# 34413/34413 [==============================] - 294s 9ms/step - loss: 0.0023 - accuracy: 0.9995 - val_loss: 0.0033 - val_accuracy: 0.9993
# Epoch 6/10
# 34413/34413 [==============================] - 277s 8ms/step - loss: 0.0022 - accuracy: 0.9995 - val_loss: 0.0021 - val_accuracy: 0.9993
# Epoch 7/10
# 34413/34413 [==============================] - 278s 8ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.0044 - val_accuracy: 0.9993
# Epoch 8/10
# 34413/34413 [==============================] - 267s 8ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.0019 - val_accuracy: 0.9993
# Epoch 9/10
# 34413/34413 [==============================] - 295s 9ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.0021 - val_accuracy: 0.9993
# Epoch 10/10
# 34413/34413 [==============================] - 293s 9ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.0031 - val_accuracy: 0.9993
# Accuracy Train: 1.000, Test: 0.999
# Epoch 1/10
# 24464/24464 [==============================] - 207s 8ms/step - loss: 0.0025 - accuracy: 0.9997 - val_loss: 6.2383e-04 - val_accuracy: 0.9999
# Epoch 2/10
# 24464/24464 [==============================] - 201s 8ms/step - loss: 0.0015 - accuracy: 0.9998 - val_loss: 0.0023 - val_accuracy: 0.9993
# Epoch 3/10
# 24464/24464 [==============================] - 210s 9ms/step - loss: 0.0014 - accuracy: 0.9998 - val_loss: 5.4687e-04 - val_accuracy: 0.9999
# Epoch 4/10
# 24464/24464 [==============================] - 194s 8ms/step - loss: 0.0014 - accuracy: 0.9998 - val_loss: 3.6336e-04 - val_accuracy: 1.0000
# Epoch 5/10
# 24464/24464 [==============================] - 174s 7ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 4.3208e-04 - val_accuracy: 0.9999
# Epoch 6/10
# 24464/24464 [==============================] - 200s 8ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 7.3015e-04 - val_accuracy: 0.9999
# Epoch 7/10
# 24464/24464 [==============================] - 212s 9ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 5.0954e-04 - val_accuracy: 0.9999
# Epoch 8/10
# 24464/24464 [==============================] - 211s 9ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 4.0781e-04 - val_accuracy: 0.9999
# Epoch 9/10
# 24464/24464 [==============================] - 212s 9ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 3.3459e-04 - val_accuracy: 1.0000
# Epoch 10/10
# 24464/24464 [==============================] - 219s 9ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 3.1945e-04 - val_accuracy: 0.9999
# Accuracy Train: 1.000, Test: 1.000
# Epoch 1/10
# 11709/11709 [==============================] - 116s 10ms/step - loss: 0.0049 - accuracy: 0.9994 - val_loss: 0.0081 - val_accuracy: 0.9985
# Epoch 2/10
# 11709/11709 [==============================] - 111s 9ms/step - loss: 0.0025 - accuracy: 0.9995 - val_loss: 0.0092 - val_accuracy: 0.9985
# Epoch 3/10
# 11709/11709 [==============================] - 111s 9ms/step - loss: 0.0025 - accuracy: 0.9995 - val_loss: 0.0089 - val_accuracy: 0.9987
# Epoch 4/10
# 11709/11709 [==============================] - 111s 9ms/step - loss: 0.0023 - accuracy: 0.9996 - val_loss: 0.0076 - val_accuracy: 0.9987
# Epoch 5/10
# 11709/11709 [==============================] - 112s 10ms/step - loss: 0.0023 - accuracy: 0.9996 - val_loss: 0.0099 - val_accuracy: 0.9985
# Epoch 6/10
# 11709/11709 [==============================] - 110s 9ms/step - loss: 0.0022 - accuracy: 0.9996 - val_loss: 0.0102 - val_accuracy: 0.9985
# Epoch 7/10
# 11709/11709 [==============================] - 106s 9ms/step - loss: 0.0022 - accuracy: 0.9996 - val_loss: 0.0110 - val_accuracy: 0.9985
# Epoch 8/10
# 11709/11709 [==============================] - 106s 9ms/step - loss: 0.0022 - accuracy: 0.9996 - val_loss: 0.0107 - val_accuracy: 0.9986
# Epoch 9/10
# 11709/11709 [==============================] - 110s 9ms/step - loss: 0.0021 - accuracy: 0.9996 - val_loss: 0.0138 - val_accuracy: 0.9984
# Epoch 10/10
# 11709/11709 [==============================] - 109s 9ms/step - loss: 0.0021 - accuracy: 0.9996 - val_loss: 0.0105 - val_accuracy: 0.9986
# Accuracy Train: 1.000, Test: 0.999
# Epoch 1/10
# 1289/1289 [==============================] - 15s 9ms/step - loss: 0.0177 - accuracy: 0.9993 - val_loss: 0.0076 - val_accuracy: 0.9996
# Epoch 2/10
# 1289/1289 [==============================] - 11s 9ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0074 - val_accuracy: 0.9996
# Epoch 3/10
# 1289/1289 [==============================] - 11s 9ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.0065 - val_accuracy: 0.9996
# Epoch 4/10
# 1289/1289 [==============================] - 12s 9ms/step - loss: 8.3731e-04 - accuracy: 0.9998 - val_loss: 0.0064 - val_accuracy: 0.9996
# Epoch 5/10
# 1289/1289 [==============================] - 11s 9ms/step - loss: 8.9156e-04 - accuracy: 0.9998 - val_loss: 0.0055 - val_accuracy: 0.9996
# Epoch 6/10
# 1289/1289 [==============================] - 11s 9ms/step - loss: 8.6772e-04 - accuracy: 0.9998 - val_loss: 0.0049 - val_accuracy: 0.9996
# Epoch 7/10
# 1289/1289 [==============================] - 11s 9ms/step - loss: 9.4243e-04 - accuracy: 0.9998 - val_loss: 0.0042 - val_accuracy: 0.9996
# Epoch 8/10
# 1289/1289 [==============================] - 12s 9ms/step - loss: 9.4148e-04 - accuracy: 0.9998 - val_loss: 0.0043 - val_accuracy: 0.9996
# Epoch 9/10
# 1289/1289 [==============================] - 11s 9ms/step - loss: 8.1975e-04 - accuracy: 0.9998 - val_loss: 0.0042 - val_accuracy: 0.9996
# Epoch 10/10
# 1289/1289 [==============================] - 11s 9ms/step - loss: 7.3956e-04 - accuracy: 0.9998 - val_loss: 0.0048 - val_accuracy: 0.9996
# Accuracy Train: 1.000, Test: 1.000
# Epoch 1/10
# 3283/3283 [==============================] - 35s 10ms/step - loss: 0.0118 - accuracy: 0.9991 - val_loss: 0.0089 - val_accuracy: 0.9985
# Epoch 2/10
# 3283/3283 [==============================] - 31s 9ms/step - loss: 0.0053 - accuracy: 0.9992 - val_loss: 0.0090 - val_accuracy: 0.9985
# Epoch 3/10
# 3283/3283 [==============================] - 31s 9ms/step - loss: 0.0051 - accuracy: 0.9992 - val_loss: 0.0092 - val_accuracy: 0.9985
# Epoch 4/10
# 3283/3283 [==============================] - 29s 9ms/step - loss: 0.0050 - accuracy: 0.9992 - val_loss: 0.0086 - val_accuracy: 0.9985
# Epoch 5/10
# 3283/3283 [==============================] - 30s 9ms/step - loss: 0.0050 - accuracy: 0.9992 - val_loss: 0.0084 - val_accuracy: 0.9985
# Epoch 6/10
# 3283/3283 [==============================] - 29s 9ms/step - loss: 0.0048 - accuracy: 0.9992 - val_loss: 0.0082 - val_accuracy: 0.9985
# Epoch 7/10
# 3283/3283 [==============================] - 30s 9ms/step - loss: 0.0048 - accuracy: 0.9992 - val_loss: 0.0087 - val_accuracy: 0.9985
# Epoch 8/10
# 3283/3283 [==============================] - 30s 9ms/step - loss: 0.0047 - accuracy: 0.9993 - val_loss: 0.0085 - val_accuracy: 0.9983
# Epoch 9/10
# 3283/3283 [==============================] - 29s 9ms/step - loss: 0.0047 - accuracy: 0.9993 - val_loss: 0.0095 - val_accuracy: 0.9985
# Epoch 10/10
# 3283/3283 [==============================] - 29s 9ms/step - loss: 0.0047 - accuracy: 0.9993 - val_loss: 0.0095 - val_accuracy: 0.9985
# Accuracy Train: 0.999, Test: 0.999
# Epoch 1/10
# 27094/27094 [==============================] - 245s 9ms/step - loss: 0.0023 - accuracy: 0.9995 - val_loss: 0.0012 - val_accuracy: 0.9994
# Epoch 2/10
# 27094/27094 [==============================] - 239s 9ms/step - loss: 8.7979e-04 - accuracy: 0.9998 - val_loss: 0.0010 - val_accuracy: 0.9996
# Epoch 3/10
# 27094/27094 [==============================] - 268s 10ms/step - loss: 7.7035e-04 - accuracy: 0.9998 - val_loss: 0.0013 - val_accuracy: 0.9994
# Epoch 4/10
# 27094/27094 [==============================] - 243s 9ms/step - loss: 6.0172e-04 - accuracy: 0.9999 - val_loss: 0.0049 - val_accuracy: 0.9992
# Epoch 5/10
# 27094/27094 [==============================] - 234s 9ms/step - loss: 6.2967e-04 - accuracy: 0.9999 - val_loss: 0.0015 - val_accuracy: 0.9996
# Epoch 6/10
# 27094/27094 [==============================] - 234s 9ms/step - loss: 5.4554e-04 - accuracy: 0.9999 - val_loss: 6.9270e-04 - val_accuracy: 0.9999
# Epoch 7/10
# 27094/27094 [==============================] - 242s 9ms/step - loss: 5.0925e-04 - accuracy: 0.9999 - val_loss: 7.0520e-04 - val_accuracy: 0.9999
# Epoch 8/10
# 27094/27094 [==============================] - 243s 9ms/step - loss: 5.7335e-04 - accuracy: 0.9999 - val_loss: 0.0019 - val_accuracy: 0.9992
# Epoch 9/10
# 27094/27094 [==============================] - 241s 9ms/step - loss: 5.4458e-04 - accuracy: 0.9999 - val_loss: 9.8598e-04 - val_accuracy: 0.9999
# Epoch 10/10
# 27094/27094 [==============================] - 245s 9ms/step - loss: 5.4511e-04 - accuracy: 0.9999 - val_loss: 0.0011 - val_accuracy: 0.9996
# Accuracy Train: 1.000, Test: 1.000

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense
from sklearn import model_selection, feature_selection, kernel_approximation, ensemble, linear_model, metrics, utils
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
for i in range (1,14):
    X = pd.read_hdf(f'/home/s2316001/codepaper/data_window_botnet{i}.h5', key='data')
    X.reset_index(drop=True, inplace=True)

    X2 = pd.read_hdf(f'/home/s2316001/codepaper/data_window3_botnet{i}.h5', key='data')
    X2.reset_index(drop=True, inplace=True)

    X = X.join(X2)

    X.drop('window_id', axis=1, inplace=True)

    y = X['Label_<lambda>']
    X.drop('Label_<lambda>', axis=1, inplace=True)
    labels = np.load(f"/home/s2316001/codepaper/data_window_botnet{i}_labels.npy", allow_pickle=True)

    #print("combined_labels:",combined_labels)
    # Split the combined data into train and test sets
    y_bin6 = y == np.where(labels == 'flow=From-Botne')[0][0]
    X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y_bin6, test_size=0.33, random_state=43,shuffle=False)
    X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
    X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))
    X_train_new, y_train_new = utils.resample(X_train, y_train, n_samples=X_train.shape[0]*10, random_state=43)
    # Build the LSTM model
    model = Sequential()
    model.add(LSTM(256, input_shape=(1, X_train.shape[2]), activation='relu', return_sequences=True))
    model.add(LSTM(128))
    model.add(Dense(1, activation='sigmoid'))
    # Compile the model
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    # Train the model
    history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=32)
    _, train_acc = model.evaluate(X_train, y_train, verbose=0)
    _, test_acc = model.evaluate(X_test, y_test, verbose=0)
    print('Accuracy Train: %.3f, Test: %.3f' % (train_acc, test_acc))
        # plot loss during training
    # plt.subplot(211)
    # plt.title('Loss')
    # plt.plot(history.history['loss'], label='train')
    # plt.plot(history.history['val_loss'], label='test')
    # plt.legend()
    # # plot accuracy during training
    # plt.subplot(212)
    # plt.title('Accuracy')
    # plt.plot(history.history['accuracy'], label='train')
    # plt.plot(history.history['val_accuracy'], label='test')
    # plt.legend()
    # plt.show()
    # Plot the loss and accuracy
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.savefig(f'/home/s2316001/codepaper/LSTM_resample/LSTM_loss_accuracy_plot{i}.png')  # Save the plot as an image file
    plt.show()
#     # predict probabilities for test set
#     yhat_probs = model.predict(X_test, verbose=0)
#     # predict crisp classes for test set
#     yhat_classes = (model.predict(X_test) > 0.5).astype("int32")
#     reduce to 1d array
#     yhat_probs = yhat_probs.reshape(yhat_probs.shape[0])
#     yhat_classes = yhat_classes.reshape(yhat_classes.shape[0])
#     print(f"---------------------- File {i} --------------------------")
#     # accuracy: (tp + tn) / (p + n)
#     accuracy = accuracy_score(y_test, yhat_classes)
#     print('Accuracy: %f' % accuracy)
#     # precision tp / (tp + fp)
#     precision = precision_score(y_test, yhat_classes)
#     print('Precision: %f' % precision)
#     # recall: tp / (tp + fn)
#     recall = recall_score(y_test, yhat_classes)
#     print('Recall: %f' % recall)
#     # f1: 2 tp / (2 tp + fp + fn)
#     f1 = f1_score(y_test, yhat_classes)
#     print('F1 score: %f' % f1)

#     confusion matrix
#     matrix = confusion_matrix(y_test, yhat_classes)
#     print(matrix)
#     Plot Confusion Matrix
#     plt.figure(figsize=(10, 8))
#     sns.heatmap(matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
#     plt.title('Confusion Matrix')
#     plt.xlabel('Predicted Labels')
#     plt.ylabel('True Labels')
#     plt.savefig(f'/home/s2316001/codepaper/graph/lstm_confusion_matrix{i}.png')
#     plt.show()
    # Save the model
    model.save(f'/home/s2316001/codepaper/LSTM_resample/lstm_model{i}.h5')
# Out:
# Epoch 1/10
# 46622/46622 [==============================] - 252s 5ms/step - loss: 6.7001e-04 - accuracy: 0.9999 - val_loss: 7.4435e-05 - val_accuracy: 1.0000
# Epoch 2/10
# 46622/46622 [==============================] - 252s 5ms/step - loss: 1.4750e-04 - accuracy: 1.0000 - val_loss: 4.2671e-05 - val_accuracy: 1.0000
# Epoch 3/10
# 46622/46622 [==============================] - 251s 5ms/step - loss: 1.3897e-04 - accuracy: 1.0000 - val_loss: 6.4403e-05 - val_accuracy: 1.0000
# Epoch 4/10
# 46622/46622 [==============================] - 247s 5ms/step - loss: 1.1939e-04 - accuracy: 1.0000 - val_loss: 7.0129e-05 - val_accuracy: 1.0000
# Epoch 5/10
# 46622/46622 [==============================] - 252s 5ms/step - loss: 1.0688e-04 - accuracy: 1.0000 - val_loss: 7.7351e-04 - val_accuracy: 0.9999
# Epoch 6/10
# 46622/46622 [==============================] - 249s 5ms/step - loss: 1.2433e-04 - accuracy: 1.0000 - val_loss: 5.4347e-05 - val_accuracy: 1.0000
# Epoch 7/10
# 46622/46622 [==============================] - 247s 5ms/step - loss: 1.1294e-04 - accuracy: 1.0000 - val_loss: 3.6461e-05 - val_accuracy: 1.0000
# Epoch 8/10
# 46622/46622 [==============================] - 251s 5ms/step - loss: 9.4448e-05 - accuracy: 1.0000 - val_loss: 6.3512e-05 - val_accuracy: 1.0000
# Epoch 9/10
# 46622/46622 [==============================] - 247s 5ms/step - loss: 9.6370e-05 - accuracy: 1.0000 - val_loss: 8.5873e-05 - val_accuracy: 1.0000
# Epoch 10/10
# 46622/46622 [==============================] - 246s 5ms/step - loss: 8.5016e-05 - accuracy: 1.0000 - val_loss: 2.4211e-05 - val_accuracy: 1.0000
# Accuracy Train: 1.000, Test: 1.000
# Epoch 1/10
# 29973/29973 [==============================] - 161s 5ms/step - loss: 0.0011 - accuracy: 0.9999 - val_loss: 2.9224e-04 - val_accuracy: 1.0000
# Epoch 2/10
# 29973/29973 [==============================] - 163s 5ms/step - loss: 3.1641e-04 - accuracy: 0.9999 - val_loss: 3.5801e-05 - val_accuracy: 1.0000
# Epoch 3/10
# 29973/29973 [==============================] - 159s 5ms/step - loss: 2.3032e-04 - accuracy: 1.0000 - val_loss: 1.4240e-04 - val_accuracy: 1.0000
# Epoch 4/10
# 29973/29973 [==============================] - 159s 5ms/step - loss: 2.4961e-04 - accuracy: 1.0000 - val_loss: 1.1152e-04 - val_accuracy: 1.0000
# Epoch 5/10
# 29973/29973 [==============================] - 161s 5ms/step - loss: 2.1990e-04 - accuracy: 1.0000 - val_loss: 1.0151e-04 - val_accuracy: 1.0000
# Epoch 6/10
# 29973/29973 [==============================] - 161s 5ms/step - loss: 2.1822e-04 - accuracy: 1.0000 - val_loss: 1.0870e-04 - val_accuracy: 1.0000
# Epoch 7/10
# 29973/29973 [==============================] - 163s 5ms/step - loss: 2.0282e-04 - accuracy: 1.0000 - val_loss: 1.5051e-04 - val_accuracy: 1.0000
# Epoch 8/10
# 29973/29973 [==============================] - 159s 5ms/step - loss: 2.0446e-04 - accuracy: 1.0000 - val_loss: 7.1280e-05 - val_accuracy: 1.0000
# Epoch 9/10
# 29973/29973 [==============================] - 157s 5ms/step - loss: 2.5237e-04 - accuracy: 1.0000 - val_loss: 8.9512e-05 - val_accuracy: 1.0000
# Epoch 10/10
# 29973/29973 [==============================] - 154s 5ms/step - loss: 2.1317e-04 - accuracy: 1.0000 - val_loss: 2.0219e-04 - val_accuracy: 0.9999
# Accuracy Train: 1.000, Test: 1.000
# Epoch 1/10
# 42379/42379 [==============================] - 227s 5ms/step - loss: 0.0015 - accuracy: 0.9999 - val_loss: 4.0452e-04 - val_accuracy: 1.0000
# Epoch 2/10
# 42379/42379 [==============================] - 222s 5ms/step - loss: 9.7092e-04 - accuracy: 0.9999 - val_loss: 3.7700e-04 - val_accuracy: 1.0000
# Epoch 3/10
# 42379/42379 [==============================] - 227s 5ms/step - loss: 9.2621e-04 - accuracy: 0.9999 - val_loss: 3.6706e-04 - val_accuracy: 1.0000
# Epoch 4/10
# 42379/42379 [==============================] - 223s 5ms/step - loss: 9.0944e-04 - accuracy: 0.9999 - val_loss: 5.2540e-04 - val_accuracy: 1.0000
# Epoch 5/10
# 42379/42379 [==============================] - 222s 5ms/step - loss: 8.6988e-04 - accuracy: 0.9999 - val_loss: 3.7098e-04 - val_accuracy: 1.0000
# Epoch 6/10
# 42379/42379 [==============================] - 226s 5ms/step - loss: 8.8323e-04 - accuracy: 0.9999 - val_loss: 3.8234e-04 - val_accuracy: 1.0000
# Epoch 7/10
# 42379/42379 [==============================] - 226s 5ms/step - loss: 9.0801e-04 - accuracy: 0.9999 - val_loss: 3.6074e-04 - val_accuracy: 1.0000
# Epoch 8/10
# 42379/42379 [==============================] - 228s 5ms/step - loss: 8.8690e-04 - accuracy: 0.9999 - val_loss: 4.2165e-04 - val_accuracy: 1.0000
# Epoch 9/10
# 42379/42379 [==============================] - 226s 5ms/step - loss: 0.0010 - accuracy: 0.9999 - val_loss: 4.3162e-04 - val_accuracy: 1.0000
# Epoch 10/10
# 42379/42379 [==============================] - 227s 5ms/step - loss: 0.0010 - accuracy: 0.9999 - val_loss: 4.8971e-04 - val_accuracy: 1.0000
# Accuracy Train: 1.000, Test: 1.000
# Epoch 1/10
# 9855/9855 [==============================] - 57s 6ms/step - loss: 0.0035 - accuracy: 0.9998 - val_loss: 0.0035 - val_accuracy: 0.9996
# Epoch 2/10
# 9855/9855 [==============================] - 56s 6ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0029 - val_accuracy: 0.9996
# Epoch 3/10
# 9855/9855 [==============================] - 51s 5ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0038 - val_accuracy: 0.9996
# Epoch 4/10
# 9855/9855 [==============================] - 54s 6ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.0038 - val_accuracy: 0.9996
# Epoch 5/10
# 9855/9855 [==============================] - 51s 5ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.0036 - val_accuracy: 0.9997
# Epoch 6/10
# 9855/9855 [==============================] - 51s 5ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.0031 - val_accuracy: 0.9996
# Epoch 7/10
# 9855/9855 [==============================] - 52s 5ms/step - loss: 9.9170e-04 - accuracy: 0.9998 - val_loss: 0.0031 - val_accuracy: 0.9996
# Epoch 8/10
# 9855/9855 [==============================] - 53s 5ms/step - loss: 9.8921e-04 - accuracy: 0.9998 - val_loss: 0.0030 - val_accuracy: 0.9996
# Epoch 9/10
# 9855/9855 [==============================] - 52s 5ms/step - loss: 9.5531e-04 - accuracy: 0.9998 - val_loss: 0.0029 - val_accuracy: 0.9996
# Epoch 10/10
# 9855/9855 [==============================] - 52s 5ms/step - loss: 9.0354e-04 - accuracy: 0.9999 - val_loss: 0.0033 - val_accuracy: 0.9996
# Accuracy Train: 1.000, Test: 1.000
# Epoch 1/10
# 1333/1333 [==============================] - 11s 7ms/step - loss: 0.0174 - accuracy: 0.9997 - val_loss: 0.0025 - val_accuracy: 0.9995
# Epoch 2/10
# 1333/1333 [==============================] - 8s 6ms/step - loss: 9.8324e-04 - accuracy: 0.9997 - val_loss: 0.0020 - val_accuracy: 0.9995
# Epoch 3/10
# 1333/1333 [==============================] - 8s 6ms/step - loss: 8.8344e-04 - accuracy: 0.9997 - val_loss: 0.0024 - val_accuracy: 0.9996
# Epoch 4/10
# 1333/1333 [==============================] - 8s 6ms/step - loss: 7.6800e-04 - accuracy: 0.9998 - val_loss: 0.0028 - val_accuracy: 0.9996
# Epoch 5/10
# 1333/1333 [==============================] - 7s 5ms/step - loss: 5.9978e-04 - accuracy: 0.9998 - val_loss: 0.0025 - val_accuracy: 0.9997
# Epoch 6/10
# 1333/1333 [==============================] - 7s 5ms/step - loss: 6.3060e-04 - accuracy: 0.9998 - val_loss: 0.0028 - val_accuracy: 0.9996
# Epoch 7/10
# 1333/1333 [==============================] - 7s 5ms/step - loss: 5.9214e-04 - accuracy: 0.9999 - val_loss: 0.0027 - val_accuracy: 0.9997
# Epoch 8/10
# 1333/1333 [==============================] - 8s 6ms/step - loss: 3.7415e-04 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 0.9997
# Epoch 9/10
# 1333/1333 [==============================] - 7s 6ms/step - loss: 5.8138e-04 - accuracy: 0.9999 - val_loss: 0.0031 - val_accuracy: 0.9995
# Epoch 10/10
# 1333/1333 [==============================] - 8s 6ms/step - loss: 4.9026e-04 - accuracy: 0.9999 - val_loss: 0.0040 - val_accuracy: 0.9994
# Accuracy Train: 1.000, Test: 0.999
# Epoch 1/10
# 4625/4625 [==============================] - 31s 6ms/step - loss: 0.0051 - accuracy: 0.9995 - val_loss: 4.1168e-04 - val_accuracy: 1.0000
# Epoch 2/10
# 4625/4625 [==============================] - 27s 6ms/step - loss: 3.6907e-04 - accuracy: 0.9999 - val_loss: 6.8588e-04 - val_accuracy: 0.9999
# Epoch 3/10
# 4625/4625 [==============================] - 26s 6ms/step - loss: 3.9657e-04 - accuracy: 0.9999 - val_loss: 3.7787e-04 - val_accuracy: 1.0000
# Epoch 4/10
# 4625/4625 [==============================] - 24s 5ms/step - loss: 3.9230e-04 - accuracy: 0.9999 - val_loss: 3.9316e-04 - val_accuracy: 1.0000
# Epoch 5/10
# 4625/4625 [==============================] - 25s 5ms/step - loss: 4.0598e-04 - accuracy: 0.9999 - val_loss: 4.2695e-04 - val_accuracy: 1.0000
# Epoch 6/10
# 4625/4625 [==============================] - 26s 6ms/step - loss: 4.5556e-04 - accuracy: 0.9999 - val_loss: 3.4902e-04 - val_accuracy: 1.0000
# Epoch 7/10
# 4625/4625 [==============================] - 25s 6ms/step - loss: 4.0988e-04 - accuracy: 0.9999 - val_loss: 4.4525e-04 - val_accuracy: 0.9999
# Epoch 8/10
# 4625/4625 [==============================] - 24s 5ms/step - loss: 3.7870e-04 - accuracy: 0.9999 - val_loss: 4.1773e-04 - val_accuracy: 1.0000
# Epoch 9/10
# 4625/4625 [==============================] - 25s 5ms/step - loss: 3.3296e-04 - accuracy: 0.9999 - val_loss: 3.4370e-04 - val_accuracy: 1.0000
# Epoch 10/10
# 4625/4625 [==============================] - 25s 5ms/step - loss: 3.6199e-04 - accuracy: 0.9999 - val_loss: 4.1952e-04 - val_accuracy: 0.9999
# Accuracy Train: 1.000, Test: 1.000
# Epoch 1/10
# 1061/1061 [==============================] - 9s 6ms/step - loss: 0.0212 - accuracy: 0.9997 - val_loss: 2.0574e-04 - val_accuracy: 1.0000
# Epoch 2/10
# 1061/1061 [==============================] - 6s 5ms/step - loss: 0.0016 - accuracy: 0.9998 - val_loss: 4.1848e-04 - val_accuracy: 1.0000
# Epoch 3/10
# 1061/1061 [==============================] - 6s 5ms/step - loss: 0.0014 - accuracy: 0.9998 - val_loss: 1.3118e-04 - val_accuracy: 1.0000
# Epoch 4/10
# 1061/1061 [==============================] - 6s 6ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 3.7848e-04 - val_accuracy: 1.0000
# Epoch 5/10
# 1061/1061 [==============================] - 6s 5ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 2.2862e-05 - val_accuracy: 1.0000
# Epoch 6/10
# 1061/1061 [==============================] - 5s 5ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 5.6512e-04 - val_accuracy: 1.0000
# Epoch 7/10
# 1061/1061 [==============================] - 6s 5ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 8.7036e-04 - val_accuracy: 1.0000
# Epoch 8/10
# 1061/1061 [==============================] - 5s 5ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 3.9583e-04 - val_accuracy: 1.0000
# Epoch 9/10
# 1061/1061 [==============================] - 6s 5ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 8.8674e-05 - val_accuracy: 1.0000
# Epoch 10/10
# 1061/1061 [==============================] - 6s 5ms/step - loss: 0.0011 - accuracy: 0.9999 - val_loss: 3.5908e-04 - val_accuracy: 1.0000
# Accuracy Train: 1.000, Test: 1.000
# Epoch 1/10
# 34413/34413 [==============================] - 200s 6ms/step - loss: 0.0036 - accuracy: 0.9995 - val_loss: 0.0038 - val_accuracy: 0.9993
# Epoch 2/10
# 34413/34413 [==============================] - 194s 6ms/step - loss: 0.0027 - accuracy: 0.9995 - val_loss: 0.0034 - val_accuracy: 0.9993
# Epoch 3/10
# 34413/34413 [==============================] - 187s 5ms/step - loss: 0.0026 - accuracy: 0.9995 - val_loss: 0.0033 - val_accuracy: 0.9993
# Epoch 4/10
# 34413/34413 [==============================] - 184s 5ms/step - loss: 0.0024 - accuracy: 0.9995 - val_loss: 0.0037 - val_accuracy: 0.9993
# Epoch 5/10
# 34413/34413 [==============================] - 181s 5ms/step - loss: 0.0023 - accuracy: 0.9995 - val_loss: 0.0031 - val_accuracy: 0.9993
# Epoch 6/10
# 34413/34413 [==============================] - 180s 5ms/step - loss: 0.0021 - accuracy: 0.9995 - val_loss: 0.0019 - val_accuracy: 0.9993
# Epoch 7/10
# 34413/34413 [==============================] - 179s 5ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.0030 - val_accuracy: 0.9993
# Epoch 8/10
# 34413/34413 [==============================] - 186s 5ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.0018 - val_accuracy: 0.9993
# Epoch 9/10
# 34413/34413 [==============================] - 192s 6ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.0019 - val_accuracy: 0.9993
# Epoch 10/10
# 34413/34413 [==============================] - 201s 6ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.0015 - val_accuracy: 0.9995
# Accuracy Train: 1.000, Test: 0.999
# Epoch 1/10
# 24464/24464 [==============================] - 145s 6ms/step - loss: 0.0025 - accuracy: 0.9997 - val_loss: 4.7659e-04 - val_accuracy: 0.9998
# Epoch 2/10
# 24464/24464 [==============================] - 138s 6ms/step - loss: 0.0015 - accuracy: 0.9998 - val_loss: 3.8489e-04 - val_accuracy: 0.9999
# Epoch 3/10
# 24464/24464 [==============================] - 146s 6ms/step - loss: 0.0015 - accuracy: 0.9998 - val_loss: 3.9191e-04 - val_accuracy: 0.9999
# Epoch 4/10
# 24464/24464 [==============================] - 148s 6ms/step - loss: 0.0014 - accuracy: 0.9998 - val_loss: 5.8793e-04 - val_accuracy: 0.9998
# Epoch 5/10
# 24464/24464 [==============================] - 136s 6ms/step - loss: 0.0014 - accuracy: 0.9998 - val_loss: 7.8318e-04 - val_accuracy: 0.9998
# Epoch 6/10
# 24464/24464 [==============================] - 139s 6ms/step - loss: 0.0014 - accuracy: 0.9998 - val_loss: 3.4448e-04 - val_accuracy: 0.9999
# Epoch 7/10
# 24464/24464 [==============================] - 135s 6ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 3.9471e-04 - val_accuracy: 0.9999
# Epoch 8/10
# 24464/24464 [==============================] - 128s 5ms/step - loss: 0.0014 - accuracy: 0.9998 - val_loss: 3.9748e-04 - val_accuracy: 0.9999
# Epoch 9/10
# 24464/24464 [==============================] - 139s 6ms/step - loss: 0.0014 - accuracy: 0.9998 - val_loss: 8.1876e-04 - val_accuracy: 0.9999
# Epoch 10/10
# 24464/24464 [==============================] - 146s 6ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 3.5859e-04 - val_accuracy: 0.9999
# Accuracy Train: 1.000, Test: 1.000
# Epoch 1/10
# 11709/11709 [==============================] - 67s 5ms/step - loss: 0.0049 - accuracy: 0.9994 - val_loss: 0.0097 - val_accuracy: 0.9986
# Epoch 2/10
# 11709/11709 [==============================] - 66s 6ms/step - loss: 0.0035 - accuracy: 0.9995 - val_loss: 0.0092 - val_accuracy: 0.9985
# Epoch 3/10
# 11709/11709 [==============================] - 64s 5ms/step - loss: 0.0027 - accuracy: 0.9995 - val_loss: 0.0083 - val_accuracy: 0.9987
# Epoch 4/10
# 11709/11709 [==============================] - 64s 5ms/step - loss: 0.0025 - accuracy: 0.9995 - val_loss: 0.0094 - val_accuracy: 0.9985
# Epoch 5/10
# 11709/11709 [==============================] - 64s 5ms/step - loss: 0.0023 - accuracy: 0.9996 - val_loss: 0.0086 - val_accuracy: 0.9985
# Epoch 6/10
# 11709/11709 [==============================] - 63s 5ms/step - loss: 0.0023 - accuracy: 0.9996 - val_loss: 0.0094 - val_accuracy: 0.9985
# Epoch 7/10
# 11709/11709 [==============================] - 64s 5ms/step - loss: 0.0022 - accuracy: 0.9996 - val_loss: 0.0085 - val_accuracy: 0.9986
# Epoch 8/10
# 11709/11709 [==============================] - 66s 6ms/step - loss: 0.0022 - accuracy: 0.9996 - val_loss: 0.0077 - val_accuracy: 0.9985
# Epoch 9/10
# 11709/11709 [==============================] - 64s 5ms/step - loss: 0.0022 - accuracy: 0.9996 - val_loss: 0.0084 - val_accuracy: 0.9985
# Epoch 10/10
# 11709/11709 [==============================] - 67s 6ms/step - loss: 0.0021 - accuracy: 0.9996 - val_loss: 0.0093 - val_accuracy: 0.9986
# Accuracy Train: 1.000, Test: 0.999
# Epoch 1/10
# 1289/1289 [==============================] - 12s 7ms/step - loss: 0.0184 - accuracy: 0.9997 - val_loss: 0.0078 - val_accuracy: 0.9996
# Epoch 2/10
# 1289/1289 [==============================] - 8s 6ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.0072 - val_accuracy: 0.9996
# Epoch 3/10
# 1289/1289 [==============================] - 8s 6ms/step - loss: 9.4145e-04 - accuracy: 0.9998 - val_loss: 0.0068 - val_accuracy: 0.9996
# Epoch 4/10
# 1289/1289 [==============================] - 8s 6ms/step - loss: 8.9726e-04 - accuracy: 0.9998 - val_loss: 0.0061 - val_accuracy: 0.9996
# Epoch 5/10
# 1289/1289 [==============================] - 8s 6ms/step - loss: 7.8777e-04 - accuracy: 0.9998 - val_loss: 0.0055 - val_accuracy: 0.9996
# Epoch 6/10
# 1289/1289 [==============================] - 8s 6ms/step - loss: 9.4696e-04 - accuracy: 0.9998 - val_loss: 0.0049 - val_accuracy: 0.9996
# Epoch 7/10
# 1289/1289 [==============================] - 8s 6ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.0041 - val_accuracy: 0.9996
# Epoch 8/10
# 1289/1289 [==============================] - 8s 6ms/step - loss: 9.7822e-04 - accuracy: 0.9998 - val_loss: 0.0044 - val_accuracy: 0.9996
# Epoch 9/10
# 1289/1289 [==============================] - 8s 6ms/step - loss: 9.0773e-04 - accuracy: 0.9998 - val_loss: 0.0043 - val_accuracy: 0.9996
# Epoch 10/10
# 1289/1289 [==============================] - 7s 6ms/step - loss: 9.1282e-04 - accuracy: 0.9998 - val_loss: 0.0039 - val_accuracy: 0.9996
# Accuracy Train: 1.000, Test: 1.000
# Epoch 1/10
# 3283/3283 [==============================] - 24s 6ms/step - loss: 0.0119 - accuracy: 0.9991 - val_loss: 0.0088 - val_accuracy: 0.9985
# Epoch 2/10
# 3283/3283 [==============================] - 18s 5ms/step - loss: 0.0053 - accuracy: 0.9992 - val_loss: 0.0097 - val_accuracy: 0.9985
# Epoch 3/10
# 3283/3283 [==============================] - 19s 6ms/step - loss: 0.0051 - accuracy: 0.9992 - val_loss: 0.0087 - val_accuracy: 0.9985
# Epoch 4/10
# 3283/3283 [==============================] - 19s 6ms/step - loss: 0.0051 - accuracy: 0.9992 - val_loss: 0.0095 - val_accuracy: 0.9985
# Epoch 5/10
# 3283/3283 [==============================] - 18s 6ms/step - loss: 0.0049 - accuracy: 0.9992 - val_loss: 0.0084 - val_accuracy: 0.9985
# Epoch 6/10
# 3283/3283 [==============================] - 18s 6ms/step - loss: 0.0047 - accuracy: 0.9993 - val_loss: 0.0087 - val_accuracy: 0.9986
# Epoch 7/10
# 3283/3283 [==============================] - 19s 6ms/step - loss: 0.0048 - accuracy: 0.9992 - val_loss: 0.0090 - val_accuracy: 0.9985
# Epoch 8/10
# 3283/3283 [==============================] - 19s 6ms/step - loss: 0.0047 - accuracy: 0.9993 - val_loss: 0.0101 - val_accuracy: 0.9974
# Epoch 9/10
# 3283/3283 [==============================] - 19s 6ms/step - loss: 0.0047 - accuracy: 0.9993 - val_loss: 0.0083 - val_accuracy: 0.9985
# Epoch 10/10
# 3283/3283 [==============================] - 20s 6ms/step - loss: 0.0046 - accuracy: 0.9993 - val_loss: 0.0091 - val_accuracy: 0.9985
# Accuracy Train: 0.999, Test: 0.999
# Epoch 1/10
# 27094/27094 [==============================] - 165s 6ms/step - loss: 0.0022 - accuracy: 0.9995 - val_loss: 0.0011 - val_accuracy: 0.9997
# Epoch 2/10
# 27094/27094 [==============================] - 146s 5ms/step - loss: 8.9330e-04 - accuracy: 0.9998 - val_loss: 5.5125e-04 - val_accuracy: 0.9998
# Epoch 3/10
# 27094/27094 [==============================] - 153s 6ms/step - loss: 7.4123e-04 - accuracy: 0.9998 - val_loss: 5.0902e-04 - val_accuracy: 0.9999
# Epoch 4/10
# 27094/27094 [==============================] - 152s 6ms/step - loss: 6.5379e-04 - accuracy: 0.9998 - val_loss: 6.9596e-04 - val_accuracy: 0.9998
# Epoch 5/10
# 27094/27094 [==============================] - 151s 6ms/step - loss: 5.9731e-04 - accuracy: 0.9999 - val_loss: 7.3015e-04 - val_accuracy: 0.9998
# Epoch 6/10
# 27094/27094 [==============================] - 153s 6ms/step - loss: 5.7927e-04 - accuracy: 0.9999 - val_loss: 9.1039e-04 - val_accuracy: 0.9998
# Epoch 7/10
# 27094/27094 [==============================] - 155s 6ms/step - loss: 6.1543e-04 - accuracy: 0.9999 - val_loss: 4.2552e-04 - val_accuracy: 0.9999
# Epoch 8/10
# 27094/27094 [==============================] - 154s 6ms/step - loss: 5.6950e-04 - accuracy: 0.9999 - val_loss: 0.0025 - val_accuracy: 0.9993
# Epoch 9/10
# 27094/27094 [==============================] - 152s 6ms/step - loss: 5.8556e-04 - accuracy: 0.9999 - val_loss: 7.1145e-04 - val_accuracy: 0.9999
# Epoch 10/10
# 27094/27094 [==============================] - 150s 6ms/step - loss: 5.3482e-04 - accuracy: 0.9999 - val_loss: 6.9677e-04 - val_accuracy: 0.9998
# Accuracy Train: 1.000, Test: 1.000
